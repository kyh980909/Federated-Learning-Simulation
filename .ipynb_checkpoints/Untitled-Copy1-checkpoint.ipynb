# %% [markdown]
# # 1. MNIST 데이터셋 가져오기

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, losses
import numpy as np
import matplotlib.pyplot as plt
from copy import copy

# %%
(x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train.reshape(60000, 28, 28, 1)
x_test = x_test.reshape(10000, 28, 28, 1)
x_train = np.pad(x_train, ((0,0), (2,2), (2,2), (0,0)), 'constant')
x_test = np.pad(x_test, ((0,0), (2,2), (2,2), (0,0)), 'constant')

# %%
idx = np.argsort(y_test)
x_train_sorted = x_test[idx]
y_train_sorted = y_test[idx]
x_eval_dataset = x_train[54842:]
y_eval_dataset = y_train[54842:]

# %% [markdown]
# # 4. 데이터 UE 별로 무작위로 나누기

# %%
import random
from collections import Counter

# %% [markdown]
# ##### 1. Balanced Dataset 5개

# %%
UE = []
for _ in range(10):
    UE.append({"x_train":[], "y_train":[]})

# %%
random.seed(45)

total = 0
random_num_list = []
for _ in range(10):
    random_num = random.randrange(1000,12000)
    total += random_num
    random_num_list.append(random_num)

print('사용한 데이터 수 :',total)
print(random_num_list)

start = 0
for i in range(10):
    if i == 0:
        UE[i]['x_train'] = x_train[:random_num_list[i]]
        UE[i]['y_train'] = y_train[:random_num_list[i]]       
    else:
        UE[i]['x_train'] = x_train[start:start+random_num_list[i]]
        UE[i]['y_train'] = y_train[start:start+random_num_list[i]]
    start += random_num_list[i]
# Out:
# 사용한 데이터 수 : 54842
# [5454, 7843, 8995, 5221, 2341, 5967, 6549, 1353, 2185, 8934]

# %%
for x in range(10):
    print(len(UE[x]['y_train']))
    
    temp = []

    for a in Counter(UE[x]['y_train']).values():
        temp.append(a)

    bar_chart = plt.bar(np.arange(10), temp, width=0.5, bottom=2, align='edge', label='A', 
                        color='b', edgecolor='black', linewidth=1.2)

    plt.title(f'UE{x+1} class distribution', pad=10)
    plt.xlabel('UE', labelpad=10)
    plt.ylabel('Data amount', labelpad=10)
    plt.show()
# Out:
# 5454
# 7843
# 8995
# 5221
# 2341
# 5967
# 6549
# 1353
# 2185
# 8934

# %% [markdown]
# ##### 2. Imbalanced Dataset 5개

# %%
UE.append({'x_train':x_test[y_test == 0], 'y_train':y_test[y_test == 0]}) # UE6

x = x_test[y_test == 1]
y = y_test[y_test == 1]
x = np.append(x, x_test[y_test == 3],axis=0)
y = np.append(y, y_test[y_test == 3],axis=0)

UE.append({'x_train':x, 'y_train':y}) # UE7

x = x_test[y_test == 2]
y = y_test[y_test == 2]
x = np.append(x, x_test[y_test == 4],axis=0)
y = np.append(y, y_test[y_test == 4],axis=0)
x = np.append(x, x_test[y_test == 9],axis=0)
y = np.append(y, y_test[y_test == 9],axis=0)

UE.append({'x_train':x, 'y_train':y}) # UE8

x = x_test[y_test == 5]
y = y_test[y_test == 5]
x = np.append(x, x_test[y_test == 6],axis=0)
y = np.append(y, y_test[y_test == 6],axis=0)

UE.append({'x_train':x, 'y_train':y}) # UE9

x = x_test[y_test == 8]
y = y_test[y_test == 8]
x = np.append(x, x_test[y_test == 7],axis=0)
y = np.append(y, y_test[y_test == 7],axis=0)

UE.append({'x_train':x, 'y_train':y}) # UE10

# %%
for x in range(5, 10):
    i = 0
    temp = []
    for a in range(10):
        if a in list(Counter(UE[x]['y_train']).keys()):
            temp.append(list(Counter(UE[x]['y_train']).values())[i])
            i += 1
        else:
            temp.append(0)

    print(temp)

    bar_chart = plt.bar(np.arange(10), temp, width=0.5, bottom=2, align='edge', label='A', 
                        color='b', edgecolor='black', linewidth=1.2)

    plt.title(f'UE{x+1} class distribution', pad=10)
    plt.xlabel('UE', labelpad=10)
    plt.ylabel('Data amount', labelpad=10)
    plt.show()
# Out:
# [577, 612, 630, 591, 570, 520, 585, 609, 585, 688]
# [665, 644, 638, 667, 746, 662, 639, 673, 594, 621]
# [129, 152, 129, 141, 126, 139, 130, 123, 145, 139]
# [239, 223, 208, 208, 236, 229, 202, 201, 211, 228]
# [902, 976, 873, 926, 870, 903, 837, 806, 912, 929]

# %% [markdown]
# # 5. 연합학습

# %%
from sklearn.model_selection import train_test_split

# %%
learning_result_list = []
for i in range(10):
    model = models.Sequential()
    model.add(layers.Conv2D(filters=6, kernel_size=(5,5), strides=1, activation='tanh', input_shape=(32, 32, 1)))
    model.add(layers.AveragePooling2D(pool_size=2, strides=2))
    model.add(layers.Conv2D(filters=16, kernel_size=(5,5), strides=1, activation='tanh'))
    model.add(layers.AveragePooling2D(pool_size=2, strides=2))
    model.add(layers.Flatten())
    model.add(layers.Dense(120, activation='tanh'))
    model.add(layers.Dense(84, activation='tanh'))
    model.add(layers.Dense(10, activation='softmax'))
    model.summary()
    x_train, x_test, y_train, y_test = train_test_split(UE[i]['x_train'], UE[i]['y_train'], test_size=0.2, random_state=45)
    model.compile(optimizer='SGD', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    learning_result_list.append(model.fit(x_train, y_train, batch_size=100, epochs=1, validation_data=(x_test, y_test)))
    tf.keras.backend.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 44/44 [==============================] - 0s 7ms/step - loss: 1.9768 - accuracy: 0.3594 - val_loss: 1.6566 - val_accuracy: 0.5830
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 63/63 [==============================] - 0s 5ms/step - loss: 1.7275 - accuracy: 0.5432 - val_loss: 1.2056 - val_accuracy: 0.7782
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 72/72 [==============================] - 0s 5ms/step - loss: 1.8032 - accuracy: 0.5138 - val_loss: 1.3340 - val_accuracy: 0.7393
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 42/42 [==============================] - 0s 9ms/step - loss: 1.8596 - accuracy: 0.4715 - val_loss: 1.4846 - val_accuracy: 0.6727
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 19/19 [==============================] - 0s 10ms/step - loss: 2.2534 - accuracy: 0.2217 - val_loss: 2.0570 - val_accuracy: 0.3348
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 48/48 [==============================] - 0s 6ms/step - loss: 1.9610 - accuracy: 0.3941 - val_loss: 1.5764 - val_accuracy: 0.6600
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 53/53 [==============================] - 0s 6ms/step - loss: 1.9026 - accuracy: 0.4449 - val_loss: 1.5228 - val_accuracy: 0.6664
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 11/11 [==============================] - 0s 19ms/step - loss: 2.3317 - accuracy: 0.1405 - val_loss: 2.2232 - val_accuracy: 0.1882
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 18/18 [==============================] - 0s 12ms/step - loss: 2.2009 - accuracy: 0.1653 - val_loss: 2.0097 - val_accuracy: 0.3822
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# 72/72 [==============================] - 0s 5ms/step - loss: 1.8859 - accuracy: 0.4606 - val_loss: 1.4236 - val_accuracy: 0.6894

# %%
UE_weights = []

for model in learning_result_list:
    layer_weights = {}
    for x in model.model.layers:
        if len(x.get_weights()) > 0:
            layer_weights[x.name] = x.get_weights()
    UE_weights.append(layer_weights)

# %%
server_model = models.Sequential()
server_model.add(layers.Conv2D(filters=6, kernel_size=(5,5), strides=1, activation='tanh', input_shape=(32, 32, 1)))
server_model.add(layers.AveragePooling2D(pool_size=2, strides=2))
server_model.add(layers.Conv2D(filters=16, kernel_size=(5,5), strides=1, activation='tanh'))
server_model.add(layers.AveragePooling2D(pool_size=2, strides=2))
server_model.add(layers.Flatten())
server_model.add(layers.Dense(120, activation='tanh'))
server_model.add(layers.Dense(84, activation='tanh'))
server_model.add(layers.Dense(10, activation='softmax'))
server_model.summary()
tf.keras.backend.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
sum_weights = {}

for i in range(len(list(UE_weights[0].keys()))):
    weight_shape = [0]
    bias_shape = [0]
    print(list(UE_weights[0].keys())[i])
    for dim in UE_weights[0][list(UE_weights[0].keys())[i]][0].shape:
        weight_shape.append(dim)
    for dim in UE_weights[0][list(UE_weights[0].keys())[i]][1].shape:
        bias_shape.append(dim)
    sum_weights.update({list(UE_weights[0].keys())[i]: {'weight': np.empty(weight_shape), 'bias':np.empty(bias_shape)}})
    
    for UE in UE_weights:
        sum_weights[list(UE.keys())[i]]['weight'] = np.append(sum_weights[list(UE.keys())[i]]['weight'], [UE[list(UE.keys())[i]][0]], axis=0)
        sum_weights[list(UE.keys())[i]]['bias'] = np.append(sum_weights[list(UE.keys())[i]]['bias'], [UE[list(UE.keys())[i]][1]], axis=0)
# Out:
# conv2d
# conv2d_1
# dense
# dense_1
# dense_2

# %%
for layer in sum_weights.keys():
    for model_layer in server_model.layers:
        if layer == model_layer.name:
            model_layer.set_weights([np.mean(sum_weights[layer]['weight'], axis=0), np.mean(sum_weights[layer]['bias'], axis=0)])

# %%
server_model.compile(optimizer='SGD', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
result = server_model.evaluate(x=x_eval_dataset, y=y_eval_dataset, batch_size=128)
# Out:
# 41/41 [==============================] - 0s 2ms/step - loss: 2.3008 - accuracy: 0.1460

# %%
print('test loss, test acc:', result)
# Out:
# test loss, test acc: [2.3008363246917725, 0.14598681032657623]

# %%
plt.imshow(x_eval_dataset[300])
print('true:',y_eval_dataset[300])
print('prediction:',np.argmax(server_model.predict(np.expand_dims(x_eval_dataset[1], axis=0))))
# Out:
# true: 1
# prediction: 4

# %%
UE_weights[0]['dense_2'][0].shape
# Out:
# (84, 10)

# %%
test = UE_weights[0]['conv2d_1'][0]

# %%
row = np.sum(test,axis=1)
row2 = np.sum(row,axis=0)

# %%
row2.shape
# Out:
# (1, 6)

# %%
row2
# Out:
# array([[-0.39288098,  0.74676037,  0.02173568,  0.6649724 ,  0.59158325,
#          0.6759901 ]], dtype=float32)

# %%
np.mean(test,axis=0)
# Out:
# array([ 2.24777218e-03,  2.12143385e-03,  6.33618038e-05, -3.94841656e-03,
#        -3.58745758e-03,  3.88966850e-03, -5.00417128e-03,  2.31946120e-03,
#        -6.03738055e-03,  4.79707494e-03, -1.00974496e-04,  4.54871403e-03,
#        -3.10955831e-04, -1.82443496e-03, -1.58082729e-03,  8.24297371e-04,
#        -4.98415949e-03, -6.99496875e-03,  6.92585483e-03,  2.08622287e-03,
#         4.75955196e-03,  4.80669178e-03, -1.55472395e-03, -1.66208207e-04,
#        -5.28737297e-03, -3.65510676e-03, -1.28519745e-03,  1.07745628e-03,
#        -6.52623363e-03,  4.41942411e-03, -1.14905764e-03, -3.61462357e-03,
#         2.06403725e-04,  1.86669279e-03, -6.21596409e-04, -3.79779638e-04,
#        -2.41960143e-03, -2.02393089e-03, -4.14099079e-03, -3.10926605e-03,
#         2.31669750e-03, -3.21303844e-03, -1.30099501e-03,  1.09628227e-03,
#        -9.33847114e-05,  2.14471808e-03, -4.66334081e-04, -1.63918105e-03,
#         4.43955592e-04,  3.56239895e-03, -8.22708826e-04,  2.79928301e-03,
#         1.76063075e-03, -4.17950423e-03,  6.15470670e-03, -1.18505955e-03,
#         2.81292410e-03, -2.59915530e-03,  4.05816687e-03,  2.02643569e-03,
#         2.87115388e-03, -6.30717445e-03,  2.82255909e-03,  2.37382506e-03,
#         1.92930130e-03, -1.40091521e-03,  8.26945703e-04, -2.21265689e-03,
#        -1.44505978e-03,  5.39572956e-03,  2.24665273e-03, -2.96013895e-03,
#         8.15920881e-04, -2.33739126e-03,  4.67952294e-03, -5.97066595e-04,
#         1.81267143e-03, -4.33689216e-03, -3.11006396e-03,  1.92320603e-03,
#        -4.06984473e-04, -1.75927102e-03, -1.50709774e-03, -4.10363218e-03,
#        -2.77645281e-03,  1.56487676e-03, -3.74642573e-03,  4.18263581e-03,
#        -1.41708518e-03, -1.43235811e-04, -6.03963435e-03, -5.67898096e-04,
#        -6.86997024e-04,  3.30259354e-04, -3.98708973e-03,  2.09505507e-03,
#         4.28439863e-03,  4.51185770e-04,  4.61811014e-03, -2.62749754e-03,
#         2.07545911e-03,  9.82727506e-04,  2.44706054e-03, -1.79889938e-03,
#        -3.27720097e-03,  3.49609344e-03,  2.27716938e-03, -8.28113931e-04,
#         1.42334227e-03, -1.13250944e-03,  4.48936271e-03, -1.27412542e-03,
#        -3.55790695e-03, -2.18484737e-03, -3.28147085e-03, -2.78615393e-03,
#        -3.16673797e-03, -5.08031715e-03, -3.23022390e-03,  5.78630902e-03],
#       dtype=float32)

# %%
def gap(weights):
    if len(weights.shape) == 4:
        row = np.mean(weights, axis=1)
        result = np.mean(row, axis=0)
    elif len(weights.shape) == 2:
        result = np.mean(weights, axis=0)
    else:
        raise print('가중치 잘못됨')
    
    return result
